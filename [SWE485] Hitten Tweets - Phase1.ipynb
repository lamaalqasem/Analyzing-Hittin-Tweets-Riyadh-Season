# %%
import pandas as pd # to use data frames
import csv # to read .CSV files

# %%
df = pd.read_csv("output_cloud.csv") 
df.head()
# Out:
#                date         username       to  replies  retweets  favorites  \
# 0   08/02/2020 9:16  SsE1j8MeFSuOZY9  sabqorg        0         0          0
# 1  04/02/2020 22:03         Bndr888_      NaN        0         0          0
# 2  24/01/2020 20:02         Bndr888_      NaN        1         0          0
# 3  21/01/2020 21:03         Bndr888_      NaN        1         0          0
# 4  19/01/2020 21:59           Gahed0      NaN        0         0          0
#
#                                                 text  geo mentions  hashtags  \
# 0  وماذا عن إزعاج ما يزيد على ستة أشهر لأحياء سكن...  NaN      NaN       NaN
# 1           عدلك يا رب #معاناه_سكان_حطين #البوليفارد  NaN      NaN       NaN
# 2  إلا قرقعة ودوشة قارفينا ببيتي قال فن قال #ليله...  NaN      NaN       NaN
# 3  ٦ شهور محبورة اعيش ببيتي والبوليفارد يردح على ...  NaN      NaN       NaN
# 4  في شويه معرصين حطين الصورة دي ، انا مش مطالبه ...  NaN      NaN       NaN
#
# ...

# %%
dText = df['text']
dText
# Out:
# 0      وماذا عن إزعاج ما يزيد على ستة أشهر لأحياء سكن...
# 1               عدلك يا رب #معاناه_سكان_حطين #البوليفارد
# 2      إلا قرقعة ودوشة قارفينا ببيتي قال فن قال #ليله...
# 3      ٦ شهور محبورة اعيش ببيتي والبوليفارد يردح على ...
# 4      في شويه معرصين حطين الصورة دي ، انا مش مطالبه ...
#                              ...
# 876    @mustafa_agha أتمنى منك عرض معاناة منطقة جازان...
# 877    @waleedalfarraj صدقني أحس إن حطين بالدرجة الثا...
# 878    @FalastinAlhura مع ان جيرانا من حطين ولوبية وص...
# 879    اليوم الطائي يحل على حطين ضيف ولسان حال العشاق...
# 880    نبارك لأهالي حطين الكرام افتتاح جمعيتنا بعد مع...
# Name: text, Length: 881, dtype: object

# %%
export_csv = dText.to_csv (r'HittenTweets.csv', index = None, header=True, encoding='utf-8-sig')
