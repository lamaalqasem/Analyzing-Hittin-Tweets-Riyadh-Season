# %% [markdown]
# # [SWE485] Hitten Tweets - Phase 2

# %%
import pandas as pd # to use data frames
import csv # to read .CSV files
import re

# %%
df = pd.read_csv("notcleaned.csv")

# %% [markdown]
# ## Assessing Data

# %%
df.head(10)

# %%
df.info()

# %%
print(sum(df.duplicated()))

# %%
df.geo.value_counts()

# %%
df.username.value_counts().head(50)

# %%
df.replies.value_counts()

# %%
df.retweets.value_counts()

# %%
df.favorites.value_counts()

# %% [markdown]
# ### Quality Issues

# %% [markdown]
# - Date Coulmn Type is not Timestamp, it can not be used to follow the timeline of the tweets and opnions.
# - Some Arabic Hashtag on the tweet will effect the classification, since they contian words indicating negitive contents.
# - Puncutaion
# - Normlizing text by replacing some letters with others.
# - Mentions

# %% [markdown]
# ### Tidness Issues

# %% [markdown]
# - Data shall be splited into day and time.
# - Some data will not be needed on the analysis

# %% [markdown]
# ## Cleaning Data

# %%
#copy dataframes
df_clean= df.copy()

# %%
#Quality 
#Convert timestamp to datetime data type.
df_clean['date'] = pd.to_datetime(df_clean.date)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881 entries, 0 to 880
# Data columns (total 12 columns):
# date         881 non-null datetime64[ns]
# username     881 non-null object
# to           205 non-null object
# replies      881 non-null int64
# retweets     881 non-null int64
# favorites    881 non-null int64
# text         881 non-null object
# geo          0 non-null float64
# mentions     174 non-null object
# hashtags     0 non-null float64
# id           881 non-null float64
# permalink    881 non-null object
# dtypes: datetime64[ns](1), float64(3), int64(3), object(5)
# memory usage: 65.4+ KB

# %%
#Tidiness 
#Split Date into day and time 
df_clean['day'] = df_clean['date'].dt.strftime('%d/%m/%Y')
df_clean['time'] = df_clean['date'].dt.strftime('%H:%M')

# %%
#Tidiness
# Delete columns we don't need anymore
df_clean = df_clean.drop('geo', 1)
df_clean = df_clean.drop('mentions', 1)
df_clean = df_clean.drop('hashtags', 1)
df_clean = df_clean.drop('id', 1)
df_clean = df_clean.drop('to', 1)
df_clean = df_clean.drop('permalink', 1)
df_clean = df_clean.drop('date', 1)
df_clean = df_clean.drop('username', 1)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881 entries, 0 to 880
# Data columns (total 6 columns):
# replies      881 non-null int64
# retweets     881 non-null int64
# favorites    881 non-null int64
# text         881 non-null object
# day          881 non-null object
# time         881 non-null object
# dtypes: int64(3), object(3)
# memory usage: 31.0+ KB

# %%
df_clean.head()
# Out:
#    replies  retweets  favorites  \
# 0        0         0          0
# 1        0         0          0
# 2        1         0          0
# 3        1         0          0
# 4        0         0          0
#
#                                                 text         day   time
# 0  وماذا عن إزعاج ما يزيد على ستة أشهر لأحياء سكن...  02/08/2020  09:16
# 1           عدلك يا رب #معاناه_سكان_حطين #البوليفارد  02/04/2020  22:03
# 2  إلا قرقعة ودوشة قارفينا ببيتي قال فن قال #ليله...  24/01/2020  20:02
# 3  ٦ شهور محبورة اعيش ببيتي والبوليفارد يردح على ...  21/01/2020  21:03
# 4  في شويه معرصين حطين الصورة دي ، انا مش مطالبه ...  19/01/2020  21:59

# %%
#Remove Arabic Hashtags
df_clean["text"] = df_clean['text'].str.replace("#[\\\p{أ-ى}_]+",' ')


#Remove Mentioned Account
df_clean["text"] = df_clean['text'].str.replace('@[^\s]+',' ')

#Remove Puncutaion
df_clean["text"] = df_clean['text'].str.replace('[^\w\s]','')

# %%
df_clean.head(60)
# Out:
#     replies  retweets  favorites  \
# 0         0         0          0
# 1         0         0          0
# 2         1         0          0
# 3         1         0          0
# 4         0         0          0
# 5         1         0          0
# 6         0         0          0
# 7         1         0          0
# 8         1         0          0
# 9         0         0          0
# 10        2         0          3
# 11        1         4          0
# 12        0         1          0
# 13        0         3          2
# 14        1         5          1
# 15        0         1          1
# 16        3         7          2
# 17        0         0          0
# 18        2         0          0
# 19        0         0          0
# 20        0         0          1
# 21        1         1          1
# 22        1         3          7
# 23        0         2          0
# 24        0         2          0
# 25        1         1          0
# 26        4         2          0
# 27        0         0          0
# 28        1         1          1
# 29        0         0          0
# 30        2         1          0
# 31        1         0          0
# 32        1         0          0
# 33        0         0          1
# 34        0         0          0
# 35        2         2          1
# 36        0         0          0
# 37        0         2          0
# 38        0         1          0
# 39        0         0          0
# 40        0         0          0
# 41        1         6          4
# 42        0         4          2
# 43        4         2          1
# 44        0         0          1
# 45        0         0          0
# 46        0         0          0
# 47        2         3          2
# 48        0         1          0
# 49        0         1          1
# 50        0         0          0
# 51        0         4          0
# 52        8        10          3
# 53        0         2          0
# 54        0         1          1
# 55        0         0          0
# 56        0         0          0
# 57        0         1          2
# 58        0         0          2
# 59        1         0          1
#
#                                                  text         day   time
# 0   وماذا عن إزعاج ما يزيد على ستة أشهر لأحياء سكن...  02/08/2020  09:16
# 1                               عدلك يا رب  ين  يفارد  02/04/2020  22:03
# 2   إلا قرقعة ودوشة قارفينا ببيتي قال فن قال  يله_...  24/01/2020  20:02
# 3   ٦ شهور محبورة اعيش ببيتي والبوليفارد يردح على ...  21/01/2020  21:03
# 4   في شويه معرصين حطين الصورة دي  انا مش مطالبه ا...  19/01/2020  21:59
# 5       حسبي الله ونعم الوكيل عدلك يا رب العالمين  ين  18/01/2020  20:01
# 6   حلول المرور مشاكل يقفلون اليوتيرن اللي عند اشا...  16/01/2020  20:50
# 7   عدلك يا رب في المسؤول عن هذا الازعاج و السماعا...  13/01/2020  20:17
# 8   اتمنى نلقى حل لهذي المشكلة جدا جدا جدا متعب ال...  01/12/2020  22:22
# 9    ين اقول روقو يااهل حطين المتر عندكم ب ٥٠٠٠الآ...  01/01/2020  10:51
# 10  ازعاج وعدم احترام للناس  ومن غير أي اعلان ان ف...  01/01/2020  08:24
# 11  نايمين في أمان الله وفجأه الساعه ١٢ الليل العا...  01/01/2020  05:25
# 12                                    هنا التعليق  ين  31/12/2019  23:32
# 13        من أعطاكم الحق في ترويع أطفالنا ونساءنا ...  31/12/2019  22:58
# 14   ين حسبي الله ونعم الوكيل الاطفاال وكبار السن ...  31/12/2019  22:56
# 15  ورجعوا يشغلون الألعاب النارية في الليل ووقت مت...  31/12/2019  22:52
# 16   ين طبيعي هالاصوات تسمعها داخل حي سكني هالوقت ...  31/12/2019  22:48
# 17                                     استغفرالله  ين  31/12/2019  22:47
# 18                         ين حسبنا الله ونعم والوكيل  31/12/2019  22:47
# 19                              جاري التفعيل  ي_حطين   31/12/2019  22:47
# 20       العاب ناريه الساعه ٢ بالليل عجزت لا انام  ين  31/12/2019  22:42
# 21   ين للان مفجوعة وما قدرت انام س١ من الانفجاربد...  31/12/2019  21:57
# 22  للاسف معاناة حي حطين ما زلت مستمره بالزحمه وال...  31/12/2019  21:36
# 23       ين الله يكون في عونكم حسبنا الله ونعم الوكيل  31/12/2019  21:30
# 24  قلة ادب ومافي اي احترام للسكان ومسئولين فاشلين...  31/12/2019  21:12
# 25   ين أكثر ناس مستعدين للقصف في حال قامت حرب لا ...  31/12/2019  21:06
# 26                          ين حسبنا الله ونعم الوكيل  31/12/2019  21:04
# 27                                            ي_حطين   28/12/2019  00:01
# 28   ين اللي مسؤول عن بوابات استديوات البوليفارد س...  26/12/2019  21:45
# 29                                         ألطم   ين   26/12/2019  02:44
# 30   ين الله الله الله اليوم الحاره رجعت لوضعها ال...  19/12/2019  19:11
# 31  يارب لك الحمد اليوم حي  ين رجع لوضعه الانساني ...  19/12/2019  15:50
# 32  اعانكم الله واضح ان فيه معاناة حقيقية تعيشونها...  19/12/2019  11:08
# 33  استفزاز هذا مو ترفيه حسبنا الله حسبنا الله ونع...  18/12/2019  23:16
# 34                                  ين عظم الله أجرنا  18/12/2019  23:10
# 35  اغاني البوليفارد اليوم بزيادة مرفعين الصوت و ا...  18/12/2019  23:04
# 36                          ين حسبنا الله ونعم الوكيل  18/12/2019  22:56
# 37  عدلك يا رب في المسؤول عن هذا الاستهتار   ين حي...  18/12/2019  22:42
# 38  حسبي الله ونعم الوكيل لا الطلاب ذاكروا ولانامو...  18/12/2019  22:40
# 39  انا بالدرعيه وانفقع راسي ما عرفت ارقد  كله كوم...  18/12/2019  22:37
# 40  الساعة ١٣٠ هذا غير منطقي والكل عنده اختبارات ن...  18/12/2019  22:32
# 41  نبي ننوم معليييش ازعاج يوم من الدرعية يوم من ا...  18/12/2019  22:31
# 42   ين يوميا في أخر الليل ردحه وإزعاج متواصل كأنه...  18/12/2019  22:10
# 43  لا مصخت مب طبيعي الوضع قبل كم يوم أصوات الألعا...  17/12/2019  21:32
# 44         متى بيطفون اغانيهم  ياض   يفارد_الرياض  ين  17/12/2019  21:31
# 45  وش هالروعه الساعه ١ونص العاب ناريه احترموا الو...  15/12/2019  22:07
# 46  فعلا البارحه ليلة الاحد قمت مفزوعه من صوت انفج...  15/12/2019  19:00
# 47                                     ين الساعة ٢ م   15/12/2019  14:46
# 48  وقت الاختبارات يتوقع ان الجميع يهتم بعيالهم وب...  15/12/2019  13:00
# 49   ين امس كنت نائمة ياربي قمت مروعة ونافذتي ع ال...  15/12/2019  11:41
# 50                              ين أبيع بيتي وين اروح  15/12/2019  10:00
# 51   ين العادة كل خميس في الساعة التاسعة نكون مستع...  14/12/2019  22:15
# 52   ين اليوم السبت وليلة دوام وش المناسبة ترا ماك...  14/12/2019  19:53
# 53  الحمد لله على سلامتك وماقصرت بس عندي سؤال  متف...  14/12/2019  19:45
# 54   ياض  ين بعد منتصف الليل وصوت الموسيقى الصادر ...  12/06/2019  23:12
# 55             يا حلو شوارع الرياض و هي فاضية  ي_حطين  12/06/2019  15:48
# 56                  الله يلعن ابو هالازعاج  يفارد  ين  12/05/2019  18:20
# 57   ين لماذا هذا الاهمال بلغوا من يضع الحواجز في ...  12/04/2019  19:36
# 58  نفس معانات  يبة حطين البنات باخر الدنيا عقارب ...  12/01/2019  21:42
# 59  إذا فيه شخص يفتي لنا سكان حي حطين مع كل فعالية...  29/11/2019  14:26

# %%
#Replace Letters
df_clean['text'] = df_clean['text'].str.replace('أ','ا')
df_clean['text'] = df_clean['text'].str.replace('إ','ا')
df_clean['text'] = df_clean['text'].str.replace('ة','ه')

# %%
df_clean.text
# Out:
# 0      وماذا عن ازعاج ما يزيد على سته اشهر لاحياء سكن...
# 1                                  عدلك يا رب  ين  يفارد
# 2      الا قرقعه ودوشه قارفينا ببيتي قال فن قال  يله_...
# 3      ٦ شهور محبوره اعيش ببيتي والبوليفارد يردح على ...
# 4      في شويه معرصين حطين الصوره دي  انا مش مطالبه ا...
#                              ...
# 876      اتمنى منك عرض معاناه منطقه جازان في توسعه مل...
# 877      صدقني احس ان حطين بالدرجه الثانيه ماله حس و ...
# 878      مع ان جيرانا من حطين ولوبيه وصفوريه والمرين ...
# 879    اليوم الطائي يحل على حطين ضيف ولسان حال العشاق...
# 880    نبارك لاهالي حطين الكرام افتتاح جمعيتنا بعد مع...
# Name: text, Length: 881, dtype: object

# %%
df_clean.to_csv(r'C:\Users\jwoha\Desktop\Cleaned.csv')
